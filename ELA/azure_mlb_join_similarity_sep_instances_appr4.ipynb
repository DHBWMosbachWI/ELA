# %%
# %%configure
# {"driverMemory":"8g","executorMemory": "8072M", "executorCores": 6, "numExecutors":12}
# Out:
# Current session configs: <tt>{u'executorCores': 6, u'numExecutors': 12, u'executorMemory': u'8072M', u'kind': 'pyspark3', u'driverMemory': u'8g'}</tt><br>
# No active sessions.

# %%
## helper_functions
"""Helper functions for the jupyter notebooks"""

REMOTE_HOST="192.168.11.3"

from os import listdir
from os.path import abspath, isfile, join
from socket import gethostname, gethostbyname
from typing import List
from pyspark.sql.dataframe import DataFrame
from pyspark.sql.types import DecimalType, DoubleType, IntegerType, StringType
from pyspark.sql.functions import col, isnan, when, count, lit

from itertools import combinations



def print_df_to_html(sparkDF: DataFrame): 
    from IPython.display import HTML
    newdf = sparkDF.toPandas()
    return HTML(newdf.to_html())

def translate_to_local_file_path(filename,directory=''):  
    if (gethostbyname(gethostname())) == REMOTE_HOST :
        if directory:
            filepath= "../{directory}/{filename}".format(directory=directory, filename=filename)
        else:
            filepath= "../{filename}".format(filename=filename)
    else:
        if directory:
            filepath= "../{directory}/{filename}".format(directory=directory, filename=filename)
        else:
            filepath= "../{filename}".format(filename=filename)
    print(abspath(filepath))   
    return "file:///path".format(path=abspath(filepath))

def translate_to_file_string(filepath):
    return "file:///path".format(path=abspath(filepath))


def translate_header_file_to_list(filepath):
   """Reads the column names from the given file and converts it to a list."""
   with open(filepath, "r") as f:
       return f.readline().rstrip().split("|")  

def translate_datatype_file_to_list(filepath) -> list:
    """reads the data types from the file, consolidates them to (string, double, int, date). 
    Retruns a list of the consolidated datatypes."""
    result = []
    #with open(filepath, "r") as f:
    raw_datatype_list = list(spark.read.option("header", "false").option("inferSchema", "true").option("delimiter", "|").csv(filepath).toPandas().iloc[0].values)
    for curr_rt in raw_datatype_list:
        if (curr_rt.startswith("smallint")):
            result.append(IntegerType())
        elif (curr_rt.startswith("decimal")):
            decimal_params = curr_rt[curr_rt.find("("):curr_rt.find(")")+1]
            num_digits = int(decimal_params[decimal_params.find("(")+1:decimal_params.find(",")])
            num_scale = int(decimal_params[decimal_params.find(",")+1:decimal_params.find(")")])
            result.append(DecimalType(num_digits, num_scale))
        elif (curr_rt.startswith("varchar")):
            result.append(StringType())
        else:
            result.append(StringType())
    return result        

def concat_files(output_file,result_dir):
    """Concats the files in the output dir do one file"""
    file_list = [f for f in listdir(result_dir) if isfile(join(result_dir, f))]
    file_list = list (map(lambda file : result_dir+"/"+file , filter(lambda x : (not x.startswith(".")) and (not x.startswith("_")), file_list)))
    print(file_list)
    with open(output_file, "w") as outfile:
        for fname in file_list:
            with open(fname) as infile:
                outfile.write(infile.read())


def variations(items :list, k :int) -> list:
    if k==0 or k>len(items):
        return [set()]
    else:
        new_result = []
        for item in items :
            for curr_set in variations(items, k-1):
                if item not in curr_set:
                    curr_set.add(item)
                    if curr_set not in new_result:
                        new_result.append(curr_set)
        return new_result

def pair_permutations_ordered(items: list) -> list:
    pair_permutations = []
    for curr_attr_set in variations(items,2):
        first_attr = curr_attr_set.pop()
        second_attr = curr_attr_set.pop()  
        pair_permutations.append([first_attr,second_attr])
        pair_permutations.append([second_attr,first_attr])
    for curr_attr in items:
        pair_permutations.append([curr_attr, curr_attr])
    return pair_permutations

def cast_datatypes(datatype_file, input_df:DataFrame) -> DataFrame:
    datatype_list  = translate_datatype_file_to_list(datatype_file)
    df = input_df.alias('tmp_df')
    if len(df.columns) == len(datatype_list):
        for i in range(len(datatype_list)):
            if datatype_list[i] != type(df.schema[i].dataType) :
                #print (f"{df.columns[i]} {datatype_list[i]} {df.schema[i].dataType}") 
                df = df.withColumn(df.columns[i],col("`{column}`".format(column=df.columns[i])).cast(datatype_list[i]))                
        return df
    else:
        return df

def check_attribute_completeness(all_columns:list, string_attributes:list, numeric_attributes:list):
    for curr_col in all_columns:
        if curr_col not in string_attributes and curr_col not in numeric_attributes :
            print ("{curr_col} is not numeric or string".format(curr_col=curr_col))

def compare_schemas(df1:DataFrame, df2:DataFrame):
    if len(df1.dtypes) != len(df2.dtypes):
        print ("Schemas have differen sizes!!!")
    else :
        for i in range(len(df1.dtypes)):
            if df1.dtypes[i][0] != df2.dtypes[i][0] or df1.dtypes[i][1] != df2.dtypes[i][1] :
                print ("Columns differ {dtype1} {dtype2}".format(dtype1=df1.dtypes[i], dtype2=df2.dtypes[i]))
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>1</td><td>application_1619121198178_0008</td><td>pyspark3</td><td>idle</td><td><a target="_blank" href="http://hn1-hadoop.g2wn5qw31z1u1ftn20ycalr0ah.ax.internal.cloudapp.net:8088/proxy/application_1619121198178_0008/">Link</a></td><td><a target="_blank" href="http://wn0-hadoop.g2wn5qw31z1u1ftn20ycalr0ah.ax.internal.cloudapp.net:30060/node/containerlogs/container_e01_1619121198178_0008_01_000001/livy">Link</a></td><td>✔</td></tr></table>
# SparkSession available as 'spark'.

# %%
import os
from pyspark import SparkConf
from pyspark.sql import SparkSession, DataFrame
from pyspark.sql.types import StringType, IntegerType, FloatType, DoubleType
from pyspark.sql.functions import udf, col, pandas_udf, PandasUDFType, collect_list, count
from scipy.stats import wasserstein_distance
from numpy import asarray
import numpy as np

# %% [markdown]
# # Create UDF for calculating EMD

# %%
@udf(returnType=FloatType())
def emd_UDF(col1, col2) -> FloatType:
    #     if len(col1) > 10:
    #         return None
    #     else:
    return float(wasserstein_distance(col1, col2))

spark.udf.register("emd_UDF", emd_UDF)
# Out:
# <function emd_UDF at 0x7f92f67c8f28>

# %% [markdown]
# # Setup MLB Tables

# %%
BENCHMARK_REL_PATH = "/DataLake/public_bi_benchmark/benchmark/"

#list_of_all_MLB_tables = [ "MLB_1", "MLB_20", "MLB_15"]
#list_of_all_MLB_tables = [ "MLB_1", "MLB_20"]
#list_of_all_MLB_tables = [ "MLB_1", "MLB_10"]
list_of_all_MLB_tables = [
     "MLB_1", "MLB_10", "MLB_11", "MLB_12", "MLB_13", "MLB_14", "MLB_15",
     "MLB_16", "MLB_17", "MLB_18", "MLB_19", "MLB_2", "MLB_20", "MLB_21",
     "MLB_22", "MLB_23", "MLB_24", "MLB_25", "MLB_26", "MLB_27", "MLB_28",
     "MLB_29", "MLB_3", "MLB_30", "MLB_31", "MLB_32", "MLB_33", "MLB_34",
     "MLB_35", "MLB_36", "MLB_37", "MLB_38", "MLB_39", "MLB_4", "MLB_40",
     "MLB_41", "MLB_42", "MLB_43", "MLB_44", "MLB_45", "MLB_46", "MLB_47",
     "MLB_48", "MLB_49", "MLB_5", "MLB_50", "MLB_51", "MLB_52", "MLB_53",
     "MLB_54", "MLB_55", "MLB_56", "MLB_57", "MLB_58", "MLB_59", "MLB_6",
     "MLB_60", "MLB_61", "MLB_62", "MLB_63", "MLB_64", "MLB_65", "MLB_66",
     "MLB_67", "MLB_68", "MLB_7", "MLB_8", "MLB_9" ]
#list_of_MLB_join_candidate_pairs = [ ("MLB_1","MLB_12"), ("MLB_1","MLB_13"), ("MLB_1","MLB_14")  ]

# %%
file_path = BENCHMARK_REL_PATH+"MLB/"
sample = False
azure_env = True

if azure_env == False:
    # create Spark Config
    conf = SparkConf()
    conf.set("spark.executor.memory", "8g")
    conf.set("spark.driver.memory", "8g")
    conf.set("spark.memory.offHeap.enabled","true" )
    conf.set("spark.memory.offHeap.size","8g") 
    conf.setMaster("local[2]")
    conf.setAppName("MLB-similarity-calc")
    # create a SparkSession
    spark = SparkSession.builder.config(conf=conf).getOrCreate()
    
# dict of string attributes for each table
string_attributes = {}
numeric_attributes = {}
for table_name in list_of_all_MLB_tables:
    if sample: 
        data_file = file_path+"samples/"+table_name+".sample"+".csv"
    else :
        data_file = file_path+table_name+".csv"
    header_file = file_path+"samples/"+table_name+".header.csv"
    datatype_file = file_path+"samples/"+table_name+".datatypes.csv"
    print(header_file)
    print(data_file)
    # create a DataFrame using an ifered Schema 
    orig_df = spark.read.option("header", "false").option("inferSchema", "true").option("delimiter", "|").csv(data_file).toDF(*spark.read.option("header", "false").option("inferSchema", "true").csv(header_file).first()[0].split("|")) 
    df = cast_datatypes(datatype_file, orig_df)
    #df = orig_df
    # compare_schemas(orig_df, df)
    df.createOrReplaceTempView(table_name)
    string_attributes[table_name] = list(filter(lambda x : not x.startswith("Calculation"), \
                                       map(lambda x : x[0], filter(lambda tupel: tupel[1] == 'string' ,df.dtypes))))
    numeric_attributes[table_name] = list(filter(lambda x : not x.startswith("Calculation"), \
                                          map(lambda x : x[0], \
                                              filter(lambda tupel: tupel[1] == 'double' or \
                                              tupel[1] == 'int' or tupel[1].startswith('decimal'),df.dtypes))))
    check_attribute_completeness(df.columns, string_attributes[table_name], numeric_attributes[table_name])
# Out:
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_1.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_1.csv
# Calculation_40532458112880653 is not numeric or string
# Calculation_40532458117070874 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_10.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_10.csv
# Calculation_40532458117263387 is not numeric or string
# Calculation_40532458113208334 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_11.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_11.csv
# Calculation_40532458117263387 is not numeric or string
# Calculation_40532458113208334 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_12.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_12.csv
# Calculation_40532458112880653 is not numeric or string
# Calculation_40532458117070874 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_13.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_13.csv
# Calculation_40532458112880653 is not numeric or string
# Calculation_40532458117070874 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_14.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_14.csv
# Calculation_40532458112880653 is not numeric or string
# Calculation_40532458117070874 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_15.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_15.csv
# Calculation_496521908233621517 is not numeric or string
# Calculation_40532458112270348 is not numeric or string
# Calculation_40532458116673561 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_16.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_16.csv
# Calculation_496521908233621517 is not numeric or string
# Calculation_40532458112270348 is not numeric or string
# Calculation_40532458116673561 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_17.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_17.csv
# Calculation_496521908233621517 is not numeric or string
# Calculation_40532458112270348 is not numeric or string
# Calculation_40532458116673561 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_18.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_18.csv
# Calculation_496521908233621517 is not numeric or string
# Calculation_40532458112270348 is not numeric or string
# Calculation_40532458116673561 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_19.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_19.csv
# Calculation_361765767527686145 is not numeric or string
# Calculation_40532458111905803 is not numeric or string
# Calculation_40532458116419608 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_2.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_2.csv
# Calculation_40532458064297984 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_20.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_20.csv
# Calculation_361765767527686145 is not numeric or string
# Calculation_40532458111905803 is not numeric or string
# Calculation_40532458116419608 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_21.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_21.csv
# Calculation_361765767527686145 is not numeric or string
# Calculation_40532458111905803 is not numeric or string
# Calculation_40532458116419608 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_22.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_22.csv
# Calculation_496521908233404428 is not numeric or string
# Calculation_40532458111283210 is not numeric or string
# Calculation_40532458116173847 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_23.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_23.csv
# Calculation_496521908233404428 is not numeric or string
# Calculation_40532458111283210 is not numeric or string
# Calculation_40532458116173847 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_24.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_24.csv
# Calculation_496521908233404428 is not numeric or string
# Calculation_40532458111283210 is not numeric or string
# Calculation_40532458116173847 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_25.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_25.csv
# Calculation_496521908233248779 is not numeric or string
# Calculation_40532458110861321 is not numeric or string
# Calculation_40532458115964950 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_26.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_26.csv
# Calculation_496521908233248779 is not numeric or string
# Calculation_40532458110861321 is not numeric or string
# Calculation_40532458115964950 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_27.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_27.csv
# Calculation_496521908233248779 is not numeric or string
# Calculation_40532458110861321 is not numeric or string
# Calculation_40532458115964950 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_28.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_28.csv
# Calculation_496521908233248779 is not numeric or string
# Calculation_40532458110861321 is not numeric or string
# Calculation_40532458115964950 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_29.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_29.csv
# Calculation_496521908233248779 is not numeric or string
# Calculation_40532458110861321 is not numeric or string
# Calculation_40532458115964950 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_3.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_3.csv
# Calculation_40532458064297984 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_30.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_30.csv
# Calculation_496521908233248779 is not numeric or string
# Calculation_40532458110861321 is not numeric or string
# Calculation_40532458115964950 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_31.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_31.csv
# Calculation_361765767503851520 is not numeric or string
# Calculation_40532458110562312 is not numeric or string
# Calculation_40532458115731477 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_32.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_32.csv
# Calculation_361765767503851520 is not numeric or string
# Calculation_40532458110562312 is not numeric or string
# Calculation_40532458115731477 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_33.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_33.csv
# Calculation_361765767503851520 is not numeric or string
# Calculation_40532458110562312 is not numeric or string
# Calculation_40532458115731477 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_34.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_34.csv
# Calculation_361765767503851520 is not numeric or string
# Calculation_40532458110562312 is not numeric or string
# Calculation_40532458115731477 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_35.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_35.csv
# Calculation_361765767503851520 is not numeric or string
# Calculation_40532458110562312 is not numeric or string
# Calculation_40532458115731477 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_36.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_36.csv
# Calculation_361765767503851520 is not numeric or string
# Calculation_40532458110562312 is not numeric or string
# Calculation_40532458115731477 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_37.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_37.csv
# Calculation_361765767503851520 is not numeric or string
# Calculation_40532458110562312 is not numeric or string
# Calculation_40532458115731477 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_38.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_38.csv
# Calculation_496521908232941578 is not numeric or string
# Calculation_40532458110046215 is not numeric or string
# Calculation_40532458115493908 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_39.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_39.csv
# Calculation_496521908232941578 is not numeric or string
# Calculation_40532458110046215 is not numeric or string
# Calculation_40532458115493908 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_4.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_4.csv
# Calculation_40532458064297984 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_40.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_40.csv
# Calculation_496521908232941578 is not numeric or string
# Calculation_40532458110046215 is not numeric or string
# Calculation_40532458115493908 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_41.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_41.csv
# Calculation_496521908230012937 is not numeric or string
# Calculation_40532458109407238 is not numeric or string
# Calculation_40532458115264531 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_42.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_42.csv
# Calculation_496521908230012937 is not numeric or string
# Calculation_40532458109407238 is not numeric or string
# Calculation_40532458115264531 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_43.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_43.csv
# Calculation_496521908230012937 is not numeric or string
# Calculation_40532458109407238 is not numeric or string
# Calculation_40532458115264531 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_44.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_44.csv
# Calculation_496521908230012937 is not numeric or string
# Calculation_40532458109407238 is not numeric or string
# Calculation_40532458115264531 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_45.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_45.csv
# Calculation_496521908229181448 is not numeric or string
# Calculation_40532458108895237 is not numeric or string
# Calculation_40532458114994194 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_46.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_46.csv
# Calculation_496521908229181448 is not numeric or string
# Calculation_40532458108895237 is not numeric or string
# Calculation_40532458114994194 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_47.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_47.csv
# Calculation_496521908229181448 is not numeric or string
# Calculation_40532458108895237 is not numeric or string
# Calculation_40532458114994194 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_48.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_48.csv
# Calculation_496521908229181448 is not numeric or string
# Calculation_40532458108895237 is not numeric or string
# Calculation_40532458114994194 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_49.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_49.csv
# Calculation_496521908228587527 is not numeric or string
# Calculation_40532458108489732 is not numeric or string
# Calculation_40532458114363409 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_5.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_5.csv
# Calculation_361765767559729157 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_50.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_50.csv
# Calculation_496521908228587527 is not numeric or string
# Calculation_40532458108489732 is not numeric or string
# Calculation_40532458114363409 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_51.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_51.csv
# Calculation_496521908228587527 is not numeric or string
# Calculation_40532458108489732 is not numeric or string
# Calculation_40532458114363409 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_52.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_52.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_53.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_53.csv
# Calculation_496521908228263942 is not numeric or string
# Calculation_212021079764389888 is not numeric or string
# Calculation_40532458107953155 is not numeric or string
# Calculation_40532458114015248 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_54.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_54.csv
# Calculation_496521908228263942 is not numeric or string
# Calculation_212021079764389888 is not numeric or string
# Calculation_40532458107953155 is not numeric or string
# Calculation_40532458114015248 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_55.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_55.csv
# Calculation_496521908228263942 is not numeric or string
# Calculation_212021079764389888 is not numeric or string
# Calculation_40532458107953155 is not numeric or string
# Calculation_40532458114015248 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_56.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_56.csv
# Calculation_496521908228263942 is not numeric or string
# Calculation_212021079764389888 is not numeric or string
# Calculation_40532458107953155 is not numeric or string
# Calculation_40532458114015248 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_57.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_57.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_58.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_58.csv
# Calculation_496521907637829636 is not numeric or string
# Calculation_212021079765098497 is not numeric or string
# Calculation_40532458107371522 is not numeric or string
# Calculation_40532458113540111 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_59.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_59.csv
# Calculation_496521907637829636 is not numeric or string
# Calculation_212021079765098497 is not numeric or string
# Calculation_40532458107371522 is not numeric or string
# Calculation_40532458113540111 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_6.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_6.csv
# Calculation_361765767559729157 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_60.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_60.csv
# Calculation_496521907637829636 is not numeric or string
# Calculation_212021079765098497 is not numeric or string
# Calculation_40532458107371522 is not numeric or string
# Calculation_40532458113540111 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_61.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_61.csv
# Calculation_496521907637829636 is not numeric or string
# Calculation_212021079765098497 is not numeric or string
# Calculation_40532458107371522 is not numeric or string
# Calculation_40532458113540111 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_62.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_62.csv
# Calculation_496521907637829636 is not numeric or string
# Calculation_212021079765098497 is not numeric or string
# Calculation_40532458107371522 is not numeric or string
# Calculation_40532458113540111 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_63.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_63.csv
# Calculation_496521907638001669 is not numeric or string
# Calculation_496521907631644673 is not numeric or string
# Calculation_496521907632136194 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_64.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_64.csv
# Calculation_496521907638001669 is not numeric or string
# Calculation_496521907631644673 is not numeric or string
# Calculation_496521907632136194 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_65.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_65.csv
# Calculation_496521907638001669 is not numeric or string
# Calculation_496521907631644673 is not numeric or string
# Calculation_496521907632136194 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_66.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_66.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_67.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_67.csv
# Calculation_40532458064297984 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_68.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_68.csv
# Calculation_361765767559729157 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_7.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_7.csv
# Calculation_40532458117263387 is not numeric or string
# Calculation_40532458113208334 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_8.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_8.csv
# Calculation_40532458117263387 is not numeric or string
# Calculation_40532458113208334 is not numeric or string
# /DataLake/public_bi_benchmark/benchmark/MLB/samples/MLB_9.header.csv
# /DataLake/public_bi_benchmark/benchmark/MLB/MLB_9.csv
# Calculation_40532458117263387 is not numeric or string
# Calculation_40532458113208334 is not numeric or string

# %%
## Calc EMD and COS just for selected combinations
for index, curr_set in enumerate(list(combinations(list_of_all_MLB_tables,2))):
    # if index > 1:
    #     break
    outer = curr_set[0]
    if outer != "MLB_1":
        break
    inner = curr_set[1]
    # skip combinations that are already calculated
    if inner in ["MLB_10","MLB_11","MLB_12","MLB_13","MLB_14","MLB_15"]:
        continue
    print(outer,inner)
    # find matching attributes to compare
    join_attributes = list(
        set(string_attributes[inner]) & set(string_attributes[outer]))
    join_condition = "ON (" + " AND ".join(map(lambda join_att : "o.`{join_att}` = i.`{join_att}`".format(join_att=join_att) ,\
                                           join_attributes))
    intersecting_attr = list(
        set(numeric_attributes[inner]) & set(numeric_attributes[outer]))
    #print(intersecting_attr)
    #create projection list
    projection_list = " , ".join(
        map(lambda attr: "o.`{attr}` as `{attr}`".format(attr=attr),
            join_attributes)
    ) + " , " + " , ".join(
        map(
            lambda attr: "o.`{attr}` as `o.{attr}` , i.`{attr}` as `i.{attr}`".
            format(attr=attr), intersecting_attr))
    sqlDF = spark.sql("SELECT "+projection_list+" FROM " +outer +" o JOIN "+ \
                            inner+ " i " + join_condition+")")
    # filter out null tupels with null values
    sqlDF = sqlDF.dropna(subset=list(
        map(lambda cur_col: "`{cur_col}`".format(cur_col=cur_col),
            sqlDF.columns)))
    
    #for max_group_count in list(range(1,9,2))+list(range(10,150,20)):
    for max_group_count in [1]:
        print(max_group_count)
        
        # groupby string attribute and filter out instances which only consider specific times
        sqlDF_instances_to_consider = sqlDF.groupby(join_attributes).agg(count(join_attributes[0]).alias("count")).where(col("count") <= max_group_count)
        resSqlDF = sqlDF.join(sqlDF_instances_to_consider, on=join_attributes, how='inner')

        attr_variations = pair_permutations_ordered(intersecting_attr)
        #print(attr_variations)

        # selsect specific attr_variation with a specific attribute included
        sel_attr = ['H','BB','X1B','X2B']
        sel_attr_variations = list(
            filter(lambda x: x[1] in sel_attr, attr_variations))
        #print(sel_attr_variations)
        #print(sel_attr_variations)
        #print(len(sel_attr_variations))

        #sel_attr_variations = [['H', "H"]]
        
        for index_attr, curr_item in enumerate(sel_attr_variations):
            result_list=[]
            #print(str(index_attr)+"/"+str(len(sel_attr_variations)))
            first_attr = curr_item[0]
            second_attr = curr_item[1]
            # print(first_attr)
            # print(second_attr)
            emd = resSqlDF.select(emd_UDF(collect_list("`o.{first_attr}`".format(first_attr=first_attr)),collect_list("`o.{second_attr}`".format(second_attr=second_attr))).alias("EMD")).collect()[0]["EMD"]
            #print([outer,first_attr, inner, second_attr, max_group_count, float(emd)])
            result_list.append([outer,first_attr, inner, second_attr, max_group_count, float(emd)])
            resultDF = spark.createDataFrame(result_list).toDF("OUTER","OUTER_ATTR","INNER","INNER_ATTR","COUNT","EMD")
            resultDF.write.format("csv").mode("overwrite").option("header", "true").save("/HdiNotebooks/semantic_data_lake/results/emd_results_sep_instances_appr4/{outer}_{inner}/emd_results_dist_sep_inst_appr4_maxgr{max_group_count}_{first_attr}_{second_attr}".format(outer=outer, inner=inner, max_group_count=max_group_count, first_attr=first_attr, second_attr=second_attr))
# Out:
# could not open socket
# Traceback (most recent call last):
#   File "/usr/hdp/current/spark2-client/python/pyspark/sql/dataframe.py", line 467, in collect
#     return list(_load_from_socket(sock_info, BatchedSerializer(PickleSerializer())))
#   File "/usr/hdp/current/spark2-client/python/pyspark/rdd.py", line 158, in _load_from_socket
#     raise Exception("could not open socket")
# Exception: could not open socket

# %%
## Calc EMD and COS just for selected combinations
for index, curr_set in enumerate(list(combinations(list_of_all_MLB_tables,2))):
    # if index > 1:
    #     break
    outer = curr_set[0]
    if outer != "MLB_1":
        break
    inner = curr_set[1]
    # skip combinations that are already calculated
    if inner in ["MLB_10"]:
        continue
    print(outer,inner)
    # find matching attributes to compare
    join_attributes = list(
        set(string_attributes[inner]) & set(string_attributes[outer]))
    join_condition = "ON (" + " AND ".join(map(lambda join_att : "o.`{join_att}` = i.`{join_att}`".format(join_att=join_att) ,\
                                           join_attributes))
    intersecting_attr = list(
        set(numeric_attributes[inner]) & set(numeric_attributes[outer]))
    #print(intersecting_attr)
    #create projection list
    projection_list = " , ".join(
        map(lambda attr: "o.`{attr}` as `{attr}`".format(attr=attr),
            join_attributes)
    ) + " , " + " , ".join(
        map(
            lambda attr: "o.`{attr}` as `o.{attr}` , i.`{attr}` as `i.{attr}`".
            format(attr=attr), intersecting_attr))
    sqlDF = spark.sql("SELECT "+projection_list+" FROM " +outer +" o JOIN "+ \
                            inner+ " i " + join_condition+")")
    # filter out null tupels with null values
    sqlDF = sqlDF.dropna(subset=list(
        map(lambda cur_col: "`{cur_col}`".format(cur_col=cur_col),
            sqlDF.columns)))
    
    #for max_group_count in list(range(1,9,2))+list(range(10,150,20)):
    for max_group_count in [3]:
        print(max_group_count)
        
        # groupby string attribute and filter out instances which only consider specific times
        sqlDF_instances_to_consider = sqlDF.groupby(join_attributes).agg(count(join_attributes[0]).alias("count")).where(col("count") <= max_group_count)
        resSqlDF = sqlDF.join(sqlDF_instances_to_consider, on=join_attributes, how='inner')

        attr_variations = pair_permutations_ordered(intersecting_attr)
        #print(attr_variations)

        # selsect specific attr_variation with a specific attribute included
        sel_attr = ['H','BB','X1B','X2B']
        sel_attr_variations = list(
            filter(lambda x: x[1] in sel_attr, attr_variations))
        #print(sel_attr_variations)
        #print(sel_attr_variations)
        #print(len(sel_attr_variations))

        #sel_attr_variations = [['H', "H"]]
        
        for index_attr, curr_item in enumerate(sel_attr_variations):
            result_list=[]
            #print(str(index_attr)+"/"+str(len(sel_attr_variations)))
            first_attr = curr_item[0]
            second_attr = curr_item[1]
            # print(first_attr)
            # print(second_attr)
            emd = resSqlDF.select(emd_UDF(collect_list("`o.{first_attr}`".format(first_attr=first_attr)),collect_list("`o.{second_attr}`".format(second_attr=second_attr))).alias("EMD")).collect()[0]["EMD"]
            #print([outer,first_attr, inner, second_attr, max_group_count, float(emd)])
            result_list.append([outer,first_attr, inner, second_attr, max_group_count, float(emd)])
            resultDF = spark.createDataFrame(result_list).toDF("OUTER","OUTER_ATTR","INNER","INNER_ATTR","COUNT","EMD")
            resultDF.write.format("csv").mode("overwrite").option("header", "true").save("/HdiNotebooks/semantic_data_lake/results/emd_results_sep_instances_appr4/{outer}_{inner}/emd_results_dist_sep_inst_appr4_maxgr{max_group_count}_{first_attr}_{second_attr}".format(outer=outer, inner=inner, max_group_count=max_group_count, first_attr=first_attr, second_attr=second_attr))
# Out:
# could not open socket: ["tried to connect to ('127.0.0.1', 37127), but an error occured: [Errno 111] Connection refused"]
# Traceback (most recent call last):
#   File "/usr/hdp/current/spark2-client/python/pyspark/sql/dataframe.py", line 535, in collect
#     return list(_load_from_socket(sock_info, BatchedSerializer(PickleSerializer())))
#   File "/usr/hdp/current/spark2-client/python/pyspark/rdd.py", line 144, in _load_from_socket
#     (sockfile, sock) = local_connect_and_auth(*sock_info)
#   File "/usr/hdp/current/spark2-client/python/pyspark/java_gateway.py", line 193, in local_connect_and_auth
#     raise Exception("could not open socket: %s" % errors)
# Exception: could not open socket: ["tried to connect to ('127.0.0.1', 37127), but an error occured: [Errno 111] Connection refused"]
